# %%
from gensim.models import word2vec

# %%
import logging
import numpy as np

# %%
def main():
    logging.basicConfig(format="%(asctime)s:%(levelname)s:%(message)s",level=logging.INFO)
    sentences = word2vec.LineSentence("C:/Users/wsl/Desktop/kaikeba/xiangmu_1/dataset/NLP/zhwiki/AA/wiki_corpus")
    model = word2vec.Word2Vec(sentences,size=250)
    #保存模型
    model.save("C:/Users/wsl/Desktop/kaikeba/xiangmu_1/dataset/NLP/zhwiki/model/wiki_corpus.model")

# %%
main()
# Out:
# 2020-02-27 14:42:26,983:WARNING:consider setting layer size to a multiple of 4 for greater performance
# 2020-02-27 14:42:26,987:INFO:collecting all words and their counts
# 2020-02-27 14:42:27,126:INFO:PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-02-27 14:42:30,046:INFO:PROGRESS: at sentence #10000, processed 6061266 words, keeping 377245 word types
# 2020-02-27 14:42:32,449:INFO:PROGRESS: at sentence #20000, processed 10894428 words, keeping 541220 word types
# 2020-02-27 14:42:34,496:INFO:PROGRESS: at sentence #30000, processed 14857572 words, keeping 665803 word types
# 2020-02-27 14:42:36,339:INFO:PROGRESS: at sentence #40000, processed 18481253 words, keeping 764630 word types
# 2020-02-27 14:42:38,029:INFO:PROGRESS: at sentence #50000, processed 21481544 words, keeping 838886 word types
# 2020-02-27 14:42:39,603:INFO:PROGRESS: at sentence #60000, processed 24411411 words, keeping 912010 word types
# ...

# %%
import logging
from gensim import models
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud
 
'''
获取一个圆形的mask
'''
def get_mask():
    x,y = np.ogrid[:300,:300]
    mask = (x-150) ** 2 + (y-150)**2 > 130 ** 2
    mask = 255 * mask.astype(int)
    return mask
 
'''
绘制词云
'''
def draw_word_cloud(word_cloud):
    wc = WordCloud(background_color="white",mask=get_mask())
    wc.generate_from_frequencies(word_cloud)
    #隐藏x轴和y轴
    plt.axis("off")
    plt.imshow(wc,interpolation="bilinear")
    plt.show()
 
def test():
    logging.basicConfig(format="%(asctime)s:%(levelname)s:%(message)s",level=logging.INFO)
    model = models.Word2Vec.load("C:/Users/wsl/Desktop/kaikeba/xiangmu_1/dataset/NLP/zhwiki/model/wiki_corpus.model")
    #输入一个词找出相似的前10个词
    one_corpus = ["人工智能"]
    result = model.most_similar(one_corpus[0],topn=100)
    #将返回的结果转换为字典,便于绘制词云
    word_cloud = dict()
    for sim in result:
        # print(sim[0],":",sim[1])
        word_cloud[sim[0]] = sim[1]
    #绘制词云
    draw_word_cloud(word_cloud)

# %%
# 在我的 notebook 里，要设置下面两行才能显示中文
plt.rcParams['font.family'] = ['sans-serif']
# 如果是在 PyCharm 里，只要下面一行，上面的一行可以删除
plt.rcParams['font.sans-serif'] = ['SimHei']

# %%
from pylab import *
mpl.rcParams['font.sans-serif'] = ['SimHei']

# %%
test()
# Out:
# 2020-02-27 15:40:15,294:INFO:loading Word2Vec object from C:/Users/wsl/Desktop/kaikeba/xiangmu_1/dataset/NLP/zhwiki/model/wiki_corpus.model
# 2020-02-27 15:40:17,393:INFO:loading wv recursively from C:/Users/wsl/Desktop/kaikeba/xiangmu_1/dataset/NLP/zhwiki/model/wiki_corpus.model.wv.* with mmap=None
# 2020-02-27 15:40:17,394:INFO:loading syn0 from C:/Users/wsl/Desktop/kaikeba/xiangmu_1/dataset/NLP/zhwiki/model/wiki_corpus.model.wv.syn0.npy with mmap=None
# 2020-02-27 15:40:22,992:INFO:setting ignored attribute syn0norm to None
# 2020-02-27 15:40:22,993:INFO:loading syn1neg from C:/Users/wsl/Desktop/kaikeba/xiangmu_1/dataset/NLP/zhwiki/model/wiki_corpus.model.syn1neg.npy with mmap=None
# 2020-02-27 15:40:28,532:INFO:setting ignored attribute cum_table to None
# 2020-02-27 15:40:28,534:INFO:loaded C:/Users/wsl/Desktop/kaikeba/xiangmu_1/dataset/NLP/zhwiki/model/wiki_corpus.model
# 2020-02-27 15:40:30,646:INFO:precomputing L2-norms of word weight vectors

# %%
# #输入两个词计算相似度
two_corpus = ["腾讯","阿里巴巴"]
    res = model.similarity(two_corpus[0],two_corpus[1])
    print("similarity:%.4f"%res)
# Out:
#   File "<ipython-input-24-a4f104ed1f9e>", line 3
#     res = model.similarity(two_corpus[0],two_corpus[1])
#     ^
# IndentationError: unexpected indent

# %%
#输入三个词类比
    three_corpus = ["北京","上海","广州"]
    res = model.most_similar([three_corpus[0],three_corpus[1],three_corpus[2]],topn=100)
    #将返回的结果转换为字典,便于绘制词云
    word_cloud = dict()
    for sim in res:
        # print(sim[0],":",sim[1])
        word_cloud[sim[0]]=sim[1]
     #绘制词云
    draw_word_cloud(word_cloud)
————————————————
版权声明：本文为CSDN博主「修炼之路」的原创文章，遵循 CC 4.0 BY-SA 版权协议，转载请附上原文出处链接及本声明。
原文链接：https://blog.csdn.net/sinat_29957455/article/details/81432846

# %%
import matplotlib
matplotlib.matplotlib_fname()
# Out:
# 'D:\\Anacoda\\envs\\kaikeba\\lib\\site-packages\\matplotlib\\mpl-data\\matplotlibrc'

# %%
import matplotlib.pyplot as plt

# 在我的 notebook 里，要设置下面两行才能显示中文
plt.rcParams['font.family'] = ['sans-serif']
# 如果是在 PyCharm 里，只要下面一行，上面的一行可以删除
plt.rcParams['font.sans-serif'] = ['SimHei']

plt.plot([0, 1], [1, 2])
plt.title('显示中文', size=16)
# dpi 设置保存文本的分辨率
plt.savefig('./first.jpg', dpi=200)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-93000f1ff52e> in <module>()
#       9 plt.title('显示中文', size=16)
#      10 # dpi 设置保存文本的分辨率
# ---> 11 plt.savefig('./first.jpg', dpi=200)
#      12 plt.show()
#
# D:\Anacoda\envs\kaikeba\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     695 def savefig(*args, **kwargs):
#     696     fig = gcf()
# --> 697     res = fig.savefig(*args, **kwargs)
#     698     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     699     return res
#
# D:\Anacoda\envs\kaikeba\lib\site-packages\matplotlib\figure.py in savefig(self, *args, **kwargs)
#    1571             self.set_frameon(frameon)
#    1572
# -> 1573         self.canvas.print_figure(*args, **kwargs)
#    1574
#    1575         if frameon:
#
# ...
